# %%
from google_images_download import google_images_download
import time
from datetime import timedelta

start_time = time.time()
response = google_images_download.googleimagesdownload()   
# arguments = {"keywords":"American_Goldfinch,Cyanocitta_Cristata,Northern_Cardinal,Cedar_Waxwing,\
#                          Chickadee,Downy_Woodpecker,Rock_Pigeon,Ruby-Troated_Hummingbird,Sparrow,\
#                          Redheaded_Woodpecker,American_Robin,Tufted_Titmouse,Prothonotary_Warbler,Prairie_Warbler", 
arguments = {"keywords":"Common_Starling,American_Crow,Mourning_Dove,House_Finch",
             "limit":1200, 
             "print_urls":True, 
             "chromedriver":"/usr/lib/chromium-browser/chromedriver"} 
paths = response.download(arguments)   
print(paths)
end_time = time.time()
time_dif = end_time - start_time
print("Time to populate dataset: " + str(timedelta(seconds=int(round(time_dif)))))
# Out:
# Item no.: 1 --> Item name = Common_Starling
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/7/7d/Toulouse_-_Sturnus_vulgaris_-_2012-02-26_-_3.jpg/220px-Toulouse_-_Sturnus_vulgaris_-_2012-02-26_-_3.jpg
# Completed Image ====> 1.220px-Toulouse_-_Sturnus_vulgaris_-_2012-02-26_-_3.jpg
# Image URL: https://www.allaboutbirds.org/guide/assets/og/75351781-1200px.jpg
# Completed Image ====> 2.75351781-1200px.jpg
# Image URL: https://media.australianmuseum.net.au/media/dd/images/common_starling.43d0693.width-800.e2d1ebf.jpg
# Completed Image ====> 3.common_starling.43d0693.width-800.e2d1ebf.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/0/0f/Colourful_starling.jpeg/310px-Colourful_starling.jpeg
# Completed Image ====> 4.310px-Colourful_starling.jpeg
# Image URL: https://www.allaboutbirds.org/guide/assets/photo/67454991-480px.jpg
# ...
